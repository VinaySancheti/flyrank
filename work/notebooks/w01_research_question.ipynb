# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VinaySancheti/flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Freestyle — Organic Search Intent & Content Optimization
#
# Why this lane: SEO teams spend thousands of hours refreshing old blog content without knowing which updates actually drive organic traffic. Focusing on search intent and ranking drop-offs allows us to target pages that have high potential upside rather than randomly updating articles

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Deciding which declining URLs receive a full content refresh versus leaving them untouched or redirecting them.
#
# Action: Content strategists re-optimize targeted pages by updating outdated information, improving search intent alignment, and adding missing subtopics.
#
# Cost of a wrong call: Re-optimizing the wrong pages wastes high-cost editorial resources and engineering hours, while ignoring high-value pages leads to permanent loss of organic market share and leads.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load dataset directly from your repository
url = "/content/sample_data/california_housing_train.csv"
df = pd.read_csv(url)

print(f"Total rows analyzed: {len(df):,}")
if 'position' in df:
    print(f"Average Position: {df['position'].mean():.2f}")
    print(f"Top-10 CTR Share: {(df['position'] <= 10).mean():.1%}")
# Out:
# Total rows analyzed: 17,000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What this work CAN claim:
#
# Observed patterns: Historical correlation between page-level features (content freshness, word count, search position) and traffic changes within this dataset.
#
# Directional guidance: Decision-support heuristics to help prioritize re-optimization queues.
#
# What this work CANNOT claim:
#
# Causal proof: Re-optimizing a page does not guarantee a top-3 ranking due to external factors like competitor actions and backlinks.
#
# Predicting Google: This model does not reverse-engineer Google's algorithm or predict future core update impacts.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
